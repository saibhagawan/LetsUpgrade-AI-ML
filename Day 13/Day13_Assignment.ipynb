# %% [markdown]
# ### Importing different required Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ### To change the path of directory to load the dataset using pandas

# %%
os.chdir("D:\\Letsupgrade_AIML\\Datasets\\")
credit_card=pd.read_csv("creditcard.csv")
credit_card.head(n=20)
# Out:
#     Time        V1        V2        V3        V4        V5        V6  \
# 0    0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1    0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2    1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3    1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4    2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# 5    2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728
# 6    4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708
# 7    7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118
# 8    7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818
# 9    9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761
# 10  10.0  1.449044 -1.176339  0.913860 -1.375667 -1.971383 -0.629152
# 11  10.0  0.384978  0.616109 -0.874300 -0.094019  2.924584  3.317027
# 12  10.0  1.249999 -1.221637  0.383930 -1.234899 -1.485419 -0.753230
# ...

# %% [markdown]
# ### To view the information about creditcard dataset

# %%
credit_card.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
# Time      284807 non-null float64
# V1        284807 non-null float64
# V2        284807 non-null float64
# V3        284807 non-null float64
# V4        284807 non-null float64
# V5        284807 non-null float64
# V6        284807 non-null float64
# V7        284807 non-null float64
# V8        284807 non-null float64
# V9        284807 non-null float64
# V10       284807 non-null float64
# V11       284807 non-null float64
# V12       284807 non-null float64
# V13       284807 non-null float64
# V14       284807 non-null float64
# V15       284807 non-null float64
# V16       284807 non-null float64
# V17       284807 non-null float64
# V18       284807 non-null float64
# V19       284807 non-null float64
# V20       284807 non-null float64
# V21       284807 non-null float64
# V22       284807 non-null float64
# V23       284807 non-null float64
# ...

# %% [markdown]
# ### To view the description about the dataset using describe() method

# %%
credit_card.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.165980e-15  3.416908e-16 -1.373150e-15  2.086869e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.490107e-15 -5.556467e-16  1.177556e-16 -2.406455e-15
# ...

# %% [markdown]
# ### Checking different observations for the amount column

# %%
amount=credit_card.loc[:,["Amount"]]
amount.head()
# Out:
#    Amount
# 0  149.62
# 1    2.69
# 2  378.66
# 3  123.50
# 4   69.99

# %%
amount.describe()
# Out:
#               Amount
# count  284807.000000
# mean       88.349619
# std       250.120109
# min         0.000000
# 25%         5.600000
# 50%        22.000000
# 75%        77.165000
# max     25691.160000

# %% [markdown]
# ### To view class and amount data in one dataframe

# %%
df1=credit_card.loc[:,["Class","Amount"]]
df1.head()
# Out:
#   Class  Amount
# 0   '0'  149.62
# 1   '0'    2.69
# 2   '0'  378.66
# 3   '0'  123.50
# 4   '0'   69.99

# %% [markdown]
# ### Checking based on grouping class, sum of the amount per each class of credit card

# %%
df1.groupby(by="Class").sum()
# Out:
#              Amount
# Class
# '0'    2.510246e+07
# '1'    6.012797e+04

# %% [markdown]
# ### To check the null values present in the dataset

# %%
credit_card.isnull().any() # (or) pd.isnull(credit_card.isnull().any())
# Out:
# Time      False
# V1        False
# V2        False
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17       False
# V18       False
# V19       False
# V20       False
# V21       False
# V22       False
# V23       False
# V24       False
# V25       False
# V26       False
# V27       False
# V28       False
# Amount    False
# Class     False
# dtype: bool

# %% [markdown]
# ### Checking the duplicate values in the dataset creditcard.csv

# %%
credit_card.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 284802    False
# 284803    False
# 284804    False
# 284805    False
# 284806    False
# Length: 284807, dtype: bool

# %% [markdown]
# ### To check for particular columns whether it is duplicated or not

# %%
credit_card.duplicated(subset=["Class"])
# Out:
# 0         False
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 284802     True
# 284803     True
# 284804     True
# 284805     True
# 284806     True
# Length: 284807, dtype: bool

# %% [markdown]
# ## Filtering for different Informations

# %% [markdown]
# ### Filter amount greater than 100 and class is '0'

# %%
filter1=credit_card.loc[((credit_card["Class"].isin(["'0'"]) & (credit_card["Amount"]>100))),["Class","Amount"]]
filter1
# Out:
#        Class  Amount
# 0        '0'  149.62
# 2        '0'  378.66
# 3        '0'  123.50
# 12       '0'  121.50
# 20       '0'  231.71
# ...      ...     ...
# 284753   '0'  337.54
# 284754   '0'  156.00
# 284757   '0'  200.00
# 284771   '0'  124.99
# 284806   '0'  217.00
#
# [56378 rows x 2 columns]

# %%
credit_card["Class"].unique()
# Out:
# array(["'0'", "'1'"], dtype=object)

# %% [markdown]
# ### Basic plots using matplotlib

# %%
#Scatter plot
plt.scatter("V1","Amount",data=credit_card)
plt.show()

# %% [markdown]
# ### Basic plots using seaborn

# %%
sns.barplot(x="Class",y="Amount",data=df1)
plt.show()

# %%
sns.scatterplot(x="V2",y="Amount",data=credit_card)
plt.show()

# %% [markdown]
# ### histogram using seaborn

# %%
sns.histplot(credit_card["Class"])
plt.show()

# %%
credit_card.hist(column=["Class","V1","V2","V3","Amount"],figsize=(15,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x21180850>,
# ...
#       dtype=object)

# %%
plt.hist("Amount",data=credit_card)
plt.show()
