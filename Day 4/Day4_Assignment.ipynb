# %% [markdown]
# ### Question 1 :Research on whether addition, subtraction, multiplication, division, floor division, and modulo operations be performed on complex numbers. Based on your study, implement a Python program to demonstrate these operations.

# %%
# initiating Two complex numbers
a=2+5j
b=4-10j
print("Addition of two complex numbers a and b is:",a+b)
print("Subtraction of two complex numbers a and b is:",a-b)
print("Multiplication of two complex numbers a and b is:",a*b)
print("Division of two complex numbers a and b is:",a*b)
# Floor division and modulo operation can't be performed on complex numbers, and returns a TypeError
print("Floor Division of two complex numbers a and b is:",a//b)
print("Modulo division of two complex numbers a and b is:",a%b)
# Out:
# Addition of two complex numbers a and b is: (6-5j)
# Subtraction of two complex numbers a and b is: (-2+15j)
# Multiplication of two complex numbers a and b is: (58+0j)
# Division of two complex numbers a and b is: (58+0j)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-e310f99b8e7b> in <module>
#       7 print("Division of two complex numbers a and b is:",a*b)
#       8 # Floor division and modulo operation can't be performed on complex numbers, and returns a TypeError
# ----> 9 print("Floor Division of two complex numbers a and b is:",a//b)
#      10 print("Modulo division of two complex numbers a and b is:",a%b)
#
# TypeError: can't take floor of complex number.

# %% [markdown]
# ### Question 2 : Research on range() functions and its parameters. Create a markdown cell and write in your own words(no copy-paste from google please) what you understand about it. Implement a small program of your choice on the same.

# %% [markdown]
# Range() function describes and generates a series of integers starting from a start value to stop value with a step of value which will be helpful for increment or decrement. And it also called as Generator function.
#
# Conventions of using range function:
# -----------------------------------------------------
#
# -> range(stop): 'Stop' value specified in range function, denotes from initial starting value to the stop value and defaut increment or decrement step is '1'
#
# -> range(start,stop): 'start' and 'stop' in range function denotes from specified 'start' value to specified 'stop' value and default increment or decrement step is '1'
#
# -> range(start,stop,step): 'start' and 'stop' in range function denotes from specified 'start' value to specified 'stop' value and increment or decrement step can be varied based on requirement of obtaining values from a container.

# %% [markdown]
# ### Question 3: Consider two numbers. Perform their subtraction and if the result of subtraction is greater than 25, print their multiplication result else print their division result.

# %%
a=50
b=20
c=a-b
if(c>25):
    print("Multiplication result of two numbers a and b is:",a*b)
else:
    print("Division result of two numbers a and b is:",a/b)
# Out:
# Multiplication result of two numbers a and b is: 1000

# %% [markdown]
# ### Question 4: Consider a list of 10 elements of integer values. If the number in the list is divisible by 2, print the result as "square of that number minus 2".

# %%
list1=[12,15,16,17,19,11,18,20,21,22]
for i in list1:
    if(i%2==0):
        print("Square of the number {0} minus 2 is:{1}".format(i,(i**2)-2))
# Out:
# Square of the number 12 minus 2 is:142
# Square of the number 16 minus 2 is:254
# Square of the number 18 minus 2 is:322
# Square of the number 20 minus 2 is:398
# Square of the number 22 minus 2 is:482

# %% [markdown]
# ### Question 5: Consider a list of 10 elements. Print all the elements in the list which are greater than 7 when that number is divided 2.

# %%
list2=[10,4,6,12,13,8,14,5,9,16]
for i in list2:
    if(i%2==0):
        if(i>7):
            print("The number {0} is greater than 7".format(i))
# Out:
# The number 10 is greater than 7
# The number 12 is greater than 7
# The number 8 is greater than 7
# The number 14 is greater than 7
# The number 16 is greater than 7
